# %%
import pandas as pd
import requests
import time

# %%
# gather hist player data
years = [2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024, 2025]
schools = ["Alabama", "Arkansas", "Auburn", "Florida", "Georgia", "Kentucky", "LSU", "Mississippi State", "Missouri", "Oklahoma", "Ole Miss", "South Carolina", "Tennessee", "Texas", "Texas A&M", "Vanderbilt"]
all_data = []

for year in years:
    for school in schools:
        time.sleep(0.5)
        r = requests.get("https://api.collegefootballdata.com/stats/player/season",
                    headers={"Authorization": "Bearer olVvNEK2/yEC2USr1s+zQWta7nLmzM4P1IwXJot9wxU8FIIKob1UPcWq45OEQkXw"},
                    params={
                            "year": year, # loop 2014 - 2025
                            "conference": "SEC",
                            "team": school, # loop schools
                            "seasonType": "both"
                    }
                    )
        data = r.json()
        all_data.extend(data)

df = pd.DataFrame(all_data)

# %%
df.to_csv("sec_player_data_2014_2025.csv", index=False)

# %%
df = pd.read_csv("sec_player_data_2014_2025.csv")

# %%
df[(df["season"] == 2014) & (df["team"] == "Tennessee")].head(20) # pivot or dict?
# Out:
#       season  playerId         player position       team conference  \
# 2852    2014    504300   Jacob Carter       WR  Tennessee        SEC
# 2853    2014    504300   Jacob Carter       WR  Tennessee        SEC
# 2854    2014    504300   Jacob Carter       WR  Tennessee        SEC
# 2855    2014    504300   Jacob Carter       WR  Tennessee        SEC
# 2856    2014    504300   Jacob Carter       WR  Tennessee        SEC
# 2857    2014    504300   Jacob Carter       WR  Tennessee        SEC
# 2858    2014    504300   Jacob Carter       WR  Tennessee        SEC
# 2859    2014    504300   Jacob Carter       WR  Tennessee        SEC
# 2860    2014    504300   Jacob Carter       WR  Tennessee        SEC
# 2861    2014    504300   Jacob Carter       WR  Tennessee        SEC
# 2862    2014    504307      Matt Darr        P  Tennessee        SEC
# 2863    2014    504307      Matt Darr        P  Tennessee        SEC
# 2864    2014    504307      Matt Darr        P  Tennessee        SEC
# 2865    2014    504307      Matt Darr        P  Tennessee        SEC
# 2866    2014    504307      Matt Darr        P  Tennessee        SEC
# 2867    2014    504307      Matt Darr        P  Tennessee        SEC
# 2868    2014    512424  Justin Worley       QB  Tennessee        SEC
# 2869    2014    512424  Justin Worley       QB  Tennessee        SEC
# 2870    2014    512424  Justin Worley       QB  Tennessee        SEC
# 2871    2014    512424  Justin Worley       QB  Tennessee        SEC
#
#          category     statType      stat
# 2852  puntReturns          AVG     6.900
# 2853  puntReturns         LONG    21.000
# 2854  puntReturns           NO     8.000
# 2855  puntReturns           TD     0.000
# 2856  puntReturns          YDS    55.000
# 2857    receiving         LONG    14.000
# 2858    receiving          REC     1.000
# 2859    receiving           TD     0.000
# 2860    receiving          YDS    14.000
# 2861    receiving          YPR    14.000
# 2862      punting        In 20    30.000
# 2863      punting         LONG    61.000
# 2864      punting           NO    80.000
# 2865      punting           TB    11.000
# 2866      punting          YDS  3378.000
# 2867      punting          YPP    42.200
# 2868      passing          ATT   252.000
# 2869      passing  COMPLETIONS   157.000
# 2870      passing          INT     8.000
# 2871      passing          PCT     0.623

# %%
# https://api.collegefootballdata.com/roster

# %%
# using player id? check endpoints,

# %%
# wrangle

# %%
# EDA
